# %%
import pandas as pd
import geopandas as gpd

# %%
nm = gpd.read_file("/Users/rebeccawagner/Documents/GitHub/GerryGainMCMC/New Mexico/New Mexico Data/s_35_vtd_2020_from_block.shp")
nm
# Out:
#        block_vtda state  Shape_Leng  Shape_Area    ID  OID_1   block_vt_1  \
# 0     35001000001    35    0.113352    0.000483     0      0  35001000001
# 1     35001000002    35    0.033215    0.000049     1      1  35001000002
# 2     35001000003    35    0.073484    0.000223     2      2  35001000003
# 3     35001000004    35    0.106772    0.000285     3      3  35001000004
# 4     35001000005    35    0.113714    0.000334     4      4  35001000005
# ...           ...   ...         ...         ...   ...    ...          ...
# 1972  35061000058    35    0.147482    0.001009  1972   1972  35061000058
# 1973  35061000059    35    0.194726    0.001432  1973   1973  35061000059
# 1974  35061000060    35    0.091329    0.000360  1974   1974  35061000060
# 1975  35061000061    35    0.080557    0.000323  1975   1975  35061000061
# 1976  35061000062    35    0.087391    0.000334  1976   1976  35061000062
#
#        total                                           geometry
# ...

# %%
nm.plot()
# Out:
# <AxesSubplot: >

# %%
nm_2 = gpd.read_file("/Users/rebeccawagner/Documents/GitHub/GerryGainMCMC/New Mexico/New Mexico Data/senate_boundaries/senate_boundaries.shp")
nm_2.head()
# Out:
#   District_N  District_1                                       COUNTY  \
# 0          1           1                                     San Juan
# 1          2           2                                     San Juan
# 2          3           3                          McKinley & San Juan
# 3          4           4                  Cibola, McKinley & San Juan
# 4          5           5  Los Alamos, Rio Arriba, Sandoval & Santa Fe
#
#                   NAME PARTYAFFIL   ADDRESS        CITY      ZIP  \
# 0    William E. Sharer          R   Box 203  Farmington  87499.0
# 1    Steven P. Neville          R  Box 1570       Aztec  87410.0
# 2           John Pinto          D   Box 163    Tohatchi  87325.0
# 3      George K. Munoz          D  Box 2679      Gallup  87305.0
# 4  Richard C. Martinez          D   Box 762    Espanola  87532.0
#
#                       FullName  LastName  \
# 0    Senator William E. Sharer    Sharer
# 1    Senator Steven P. Neville   Neville
# ...

# %%
nm_2.plot(column="District_N",figsize=(12,12),colormap='gist_ncar')
# Out:
# /Users/rebeccawagner/opt/anaconda3/envs/gerry/lib/python3.10/site-packages/geopandas/plotting.py:642: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   warnings.warn(
# <AxesSubplot: >

# %%
nm_2.iloc[5]['geometry']

# %%
vtd_blk = pd.read_csv("/Users/rebeccawagner/Documents/GitHub/GerryGainMCMC/New Mexico/New Mexico Data/voting_tab_block_correspondence_35.csv")
vtd_blk.head()
# Out:
#              geoid   block_vtda  total
# 0  350010001071000  35001000564    343
# 1  350010001071001  35001000564     17
# 2  350010001071002  35001000564     46
# 3  350010001071003  35001000564     36
# 4  350010001071004  35001000564     35

# %%
len(vtd_blk['block_vtda'].unique())
# Out:
# 1977

# %%
demo = pd.read_csv('/Users/rebeccawagner/Documents/GitHub/GerryGainMCMC/Data/Block Local Environments by State/NM_LE')
demo.head()
# Out:
#    block_geoid_end  block_geoid_start    sl_dist  rn_total_sl_dist  \
# 0  350010047121049    350010001071001  14.862604            705832
# 1  350010047443044    350010001071002  14.991740            705821
# 2  350010047333006    350010001071003  15.040184            705825
# 3  350010047331011    350010001071004  14.839900            705808
# 4  350430107051015    350010001071005  14.613039            705866
#
#    rn_hisp_sl_dist  rn_nh_white_sl_dist  rn_nh_black_sl_dist  state_fips  \
# 0           324863               285837                18276          35
# 1           322949               287160                18263          35
# 2           322467               287566                18270          35
# 3           324771               285896                18271          35
# 4           325683               285198                18295          35
#
#            geoid20            geoid  ...  hisp  nh_white  nh_black  nh_na  \
# ...

# %%
demo.columns
# Out:
# Index(['block_geoid_end', 'block_geoid_start', 'sl_dist', 'rn_total_sl_dist',
#        'rn_hisp_sl_dist', 'rn_nh_white_sl_dist', 'rn_nh_black_sl_dist',
#        'state_fips', 'geoid20', 'geoid', 'total', 'lat', 'lon', 'hisp',
#        'nh_white', 'nh_black', 'nh_na', 'nh_asn', 'nh_haw', 'nh_oth',
#        'nh_multi', 'block_id_crosswalk', '_merge'],
#       dtype='object')
