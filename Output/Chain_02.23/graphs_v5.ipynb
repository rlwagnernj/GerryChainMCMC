# %%
import pandas as pd
import numpy as np
import os 
from glob import glob 
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cbook as cbook

# %%
OUTPUT = "/Users/rebeccawagner/Documents/GitHub/GerryGainMCMC/Output/Chain_02.23/scores"

pattern = os.path.join(OUTPUT, 'RunOne' + '_segregation' + '*')
files = glob(pattern)

n=len(files)*2000
scores = [np.zeros(n) for i in range(7)]

# %%
file = files[0]
df = pd.read_csv(file,names=[1,2,3,4,5,6,7])
df = df.transpose()

# %%
df
# Out:
#        1         2         3         4         5         6         7     \
# 1 -0.149787 -0.149787  0.618109 -0.630398 -0.630398 -0.038121 -0.038121
# 2 -1.804938 -6.086855 -6.882832 -5.612239 -5.612239 -6.199369 -6.199369
# 3 -3.710247  0.306840  0.306840  0.306840  0.306840  0.306840  0.306840
# 4 -6.648897 -6.648897 -6.648897 -6.648897 -1.142537 -1.142537 -1.142537
# 5 -5.278599 -5.278599 -5.278599 -5.278599 -5.278599 -5.278599  0.528386
# 6  0.791407  0.791407  0.791407  0.791407 -4.702551 -4.702551 -4.702551
# 7  0.255224  0.255224  0.255224  0.255224  0.255224  0.255224 -5.515976
#
#        8         9         10    ...      1991      1992      1993      1994  \
# 1 -0.038121 -0.038121 -0.038121  ... -1.671026  2.907107  2.907107  2.907107
# 2 -6.199369 -6.199369 -6.199369  ... -1.914662 -1.914662 -1.759211 -2.387590
# 3  0.306840  0.880226  0.880226  ... -0.400539 -0.400539 -0.562702  0.067087
# 4 -5.601765 -5.601765 -5.601765  ... -4.652837 -4.652837 -4.652837 -4.652837
# 5  0.528386  0.528386  0.528386  ... -5.606284 -5.606284 -5.606284 -5.606284
# 6 -4.702551 -4.702551 -1.928866  ...  0.723623  0.723623  0.723623  0.723623
# 7 -1.057268 -1.628087 -4.417922  ... -3.285088 -7.846036 -7.846036 -7.846036
#
#        1995      1996      1997      1998      1999      2000
# 1  2.907107  2.907107  2.907107  2.907107  2.185290  2.185290
# 2 -3.088392 -3.088392 -1.328690 -1.328690 -1.328690 -0.043434
# 3  0.771718  0.771718  0.771718  0.771718  0.771718 -0.512501
# 4 -4.652837 -8.297100 -8.297100 -8.297100 -7.578157 -7.578157
# 5 -5.606284 -5.606284 -5.606284 -4.709465 -4.709465 -4.709465
# 6  0.723623  0.723623 -1.032693 -1.917306 -1.917306 -1.917306
# 7 -7.846036 -4.217839 -4.217839 -4.217839 -4.217839 -4.217839
#
# [7 rows x 2000 columns]

# %%
df = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
df
# Out:
#        1         2         3         4         5         6         7     \
# 1 -6.648897 -6.648897 -6.882832 -6.648897 -5.612239 -6.199369 -6.199369
# 2 -5.278599 -6.086855 -6.648897 -5.612239 -5.278599 -5.278599 -5.515976
# 3 -3.710247 -5.278599 -5.278599 -5.278599 -4.702551 -4.702551 -4.702551
# 4 -1.804938 -0.149787  0.255224 -0.630398 -1.142537 -1.142537 -1.142537
# 5 -0.149787  0.255224  0.306840  0.255224 -0.630398 -0.038121 -0.038121
# 6  0.255224  0.306840  0.618109  0.306840  0.255224  0.255224  0.306840
# 7  0.791407  0.791407  0.791407  0.791407  0.306840  0.306840  0.528386
#
#        8         9         10    ...      1991      1992      1993      1994  \
# 1 -6.199369 -6.199369 -6.199369  ... -5.606284 -7.846036 -7.846036 -7.846036
# 2 -5.601765 -5.601765 -5.601765  ... -4.652837 -5.606284 -5.606284 -5.606284
# 3 -4.702551 -4.702551 -4.417922  ... -3.285088 -4.652837 -4.652837 -4.652837
# 4 -1.057268 -1.628087 -1.928866  ... -1.914662 -1.914662 -1.759211 -2.387590
# 5 -0.038121 -0.038121 -0.038121  ... -1.671026 -0.400539 -0.562702  0.067087
# 6  0.306840  0.528386  0.528386  ... -0.400539  0.723623  0.723623  0.723623
# 7  0.528386  0.880226  0.880226  ...  0.723623  2.907107  2.907107  2.907107
#
#        1995      1996      1997      1998      1999      2000
# 1 -7.846036 -8.297100 -8.297100 -8.297100 -7.578157 -7.578157
# 2 -5.606284 -5.606284 -5.606284 -4.709465 -4.709465 -4.709465
# 3 -4.652837 -4.217839 -4.217839 -4.217839 -4.217839 -4.217839
# 4 -3.088392 -3.088392 -1.328690 -1.917306 -1.917306 -1.917306
# 5  0.723623  0.723623 -1.032693 -1.328690 -1.328690 -0.512501
# 6  0.771718  0.771718  0.771718  0.771718  0.771718 -0.043434
# 7  2.907107  2.907107  2.907107  2.907107  2.185290  2.185290
#
# [7 rows x 2000 columns]

# %%
df.iloc[0][2000]
# Out:
# -7.578157297785669

# %%
scores[0][0:2000] = df.iloc[0]

# %%
scores[0][1999]
# Out:
# -7.578157297785669

# %%
scores[0][2000:4000] = df.iloc[1]

# %%
scores[0][2000]
# Out:
# -5.278599351933622

# %%
for i, file in enumerate(files):
    df = pd.read_csv(file,names=[1,2,3,4,5,6,7])
    df = df.transpose()
    df = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    for j in range(7):
        scores[j][0+2000*i:2000+2000*i] = df.iloc[j]

# %%
[np.mean(scores[i]) for i in range(7)]
# Out:
# [-8.998134678183417,
#  -6.203419537691589,
#  -3.902131566815767,
#  -1.3244890515440204,
#  -0.28525384207054233,
#  0.7296014457808133,
#  3.180543146494178]

# %%
## Boxplot Settings ====================

# Number of iterations to compare for each set of boxes
#steps = [100, 1000, 10000]
n_trials = 1000000
n_dists = 7

n_steps = 5
steps = np.logspace(2, np.log10(n_trials), n_steps).astype(int)

# Settings for whiskers

# Default - 1.5 of IQR
whis = 1.5

# 1st and 99th percentiles
#whis = [1, 99]

# Min and max
#whis = [0, 100]

# Boxplot properties
#      more examples: https://matplotlib.org/3.1.1/gallery/statistics/boxplot.html

flierprops = dict(marker='.', 
                  markersize=0) # Setting to 0 turns fliers off

medianprops = dict(linestyle='-',
                   color='k')

boxprops = dict(color='k')

## KDE settings

# Have the opportunity to get more granular here
n_steps_kde = 10
kde_steps = np.logspace(2, np.log10(n_trials), n_steps_kde).astype(int)

# %%
steps
# Out:
# array([    100,    1000,   10000,  100000, 1000000])

# %%
colors = ['cornflowerblue','teal','red','darkorange','rebeccapurple']

import matplotlib.patches as mpatches

patch_1 = mpatches.Patch(color='cornflowerblue', label='100 Iterations')
patch_2 = mpatches.Patch(color='teal', label='1,000 Iterations')
patch_3 = mpatches.Patch(color='red', label='10,000 Iterations')
patch_4 = mpatches.Patch(color='darkorange', label='100,000 Iterations')
patch_5 = mpatches.Patch(color='rebeccapurple', label='1,000,000 Iterations')

# %%
stats = []
for i in range(7):
    for s in steps:
        stats.append(cbook.boxplot_stats(scores[i][0:s], whis = whis)[0])

# %%
stats[0:5]
# Out:
# [{'mean': -6.953315092112287,
#   'iqr': 2.8131330296018815,
#   'cilo': -7.016468098382664,
#   'cihi': -6.133144327087673,
#   'whishi': -3.9341481657140456,
#   'whislo': -10.561549977619412,
#   'fliers': array([-12.85867584]),
#   'q1': -8.41542267509093,
#   'med': -6.574806212735169,
#   'q3': -5.602289645489049},
#  {'mean': -8.909060913670503,
#   'iqr': 2.0971748303178295,
#   'cilo': -9.06095388107736,
#   'cihi': -8.852713818854383,
#   'whishi': -4.76398807670094,
#   'whislo': -13.098412839304494,
#   'fliers': array([-14.24948928, -14.24948928, -14.754987  , -13.67692558,
#          -13.58568426, -13.58568426, -14.31526749, -13.2168678 ,
#          -13.37087549, -13.37087549, -13.37087549, -14.65120953,
#          -14.65120953, -14.65120953, -14.65120953, -14.65120953,
#          -14.79677055, -14.79677055,  -3.93414817,  -3.93414817,
#           -3.93414817,  -3.93414817,  -3.93414817,  -3.93414817,
#           -3.93414817,  -4.44038393,  -3.93414817,  -3.93414817,
#           -4.11130412,  -4.19592355]),
#   'q1': -9.956144437683832,
#   'med': -8.956833849965872,
#   'q3': -7.858969607366003},
#  {'mean': -9.010059437002466,
#   'iqr': 2.6311280623681537,
#   'cilo': -8.909764610902757,
#   'cihi': -8.827147189744396,
#   'whishi': -3.82289908812632,
#   'whislo': -14.315267487729216,
#   'fliers': array([-14.754987  , -14.65120953, -14.65120953, -14.65120953,
#          -14.65120953, -14.65120953, -14.79677055, -14.79677055,
#          -16.16307041, -16.09565497, -14.46491066, -14.46491066,
#          -14.35551562, -14.35551562, -14.35551562, -14.84196102,
#          -16.35943633, -14.50456757, -14.50456757, -14.95497677,
#          -14.33646916, -14.33646916, -14.43655492, -14.43655492,
#          -14.43655492, -14.40210868, -14.40210868, -14.40210868,
#          -14.40210868, -14.40210868, -14.50456757, -14.50456757,
#          -14.95497677, -14.9057623 , -14.9057623 , -14.9057623 ,
#          -15.55212401, -15.55212401, -14.59318715, -14.93452766,
#          -14.93452766, -14.93452766, -15.27430909, -15.27430909,
#          -15.27430909, -15.27430909, -15.27430909, -15.09413228,
#          -15.09413228, -15.09413228, -15.09413228, -15.09413228,
#          -14.76230563, -14.76230563, -14.76230563, -14.76230563,
#          -15.16800822, -15.16800822, -15.16800822, -15.16800822,
#          -15.16800822, -15.13216561, -15.14193095, -15.14193095,
#          -15.14193095, -15.14193095, -15.14193095, -15.14193095,
#          -15.14193095, -14.38710547, -14.44693601, -14.44693601,
#          -14.44693601, -14.44693601, -14.44693601, -14.44693601,
#           -3.69896958,  -3.79782622]),
#   'q1': -10.376340039194048,
#   'med': -8.868455900323577,
#   'q3': -7.745211976825894},
#  {'mean': -8.972565270343116,
#   'iqr': 2.6506662476667664,
#   'cilo': -8.863324916337213,
#   'cihi': -8.837004988386198,
#   'whishi': -3.6989695757365055,
#   'whislo': -14.29027036848191,
#   'fliers': array([-14.754987  , -14.31526749, -14.65120953, ...,  -3.53052792,
#           -3.53052792,  -3.56308203]),
#   'q1': -10.317034289246514,
#   'med': -8.850164952361705,
#   'q3': -7.666368041579748},
#  {'mean': -9.002587572947364,
#   'iqr': 2.683686598119003,
#   'cilo': -8.888751050417325,
#   'cihi': -8.880324274499232,
#   'whishi': -3.6989695757365055,
#   'whislo': -14.387105473838696,
#   'fliers': array([-14.754987  , -14.65120953, -14.65120953, ...,  -3.56308203,
#           -3.56308203,  -3.56308203]),
#   'q1': -10.376340039194048,
#   'med': -8.884537662458278,
#   'q3': -7.692653441075045}]

# %%
pos = np.arange(0, len(steps))
box_pos = pos + 1
#box_pos += range(len(box_pos))

tick_pos = box_pos + (len(steps)+1)/2 - 1

# %%
box_pos
# Out:
# array([1, 2, 3, 4, 5])

# %%
list(range(n_dists))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
fig, ax = plt.subplots(figsize=(12,6))
# Looping over each subset of data (e.g, 100 trials, 1000 trials, etc.)
for i in range(n_dists):
    data = stats[0+5*i:5+5*i]
    # Create the boxplots
    ax.bxp(data, positions = box_pos+6*i, 
           widths=0.5,
           boxprops = dict(color=colors[i]),
           flierprops = flierprops,
           medianprops = dict(linestyle='-',
                   color=colors[i])
          )
    pos = pos+6

#plt.xticks(tick_pos, [1,2,3,4,5,6,7], rotation=0)
plt.ylabel('Areal Unit Segregation')
plt.text(19.5,-25,'District ID')
plt.legend(handles=[patch_1, patch_2, patch_3, patch_4, patch_5], loc='upper right')
#plt.savefig('convergence_bars')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Untitled-2.ipynb Cell 21 in 8
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=3'>4</a>     data = stats[0+5*i:5+5*i]
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=4'>5</a>     # Create the boxplots
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=5'>6</a>     ax.bxp(data, positions = box_pos+6*i,
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=6'>7</a>            widths=0.5,
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=7'>8</a>            boxprops = dict(color=colors[i]),
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=8'>9</a>            flierprops = flierprops,
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=9'>10</a>            medianprops = dict(linestyle='-',
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=10'>11</a>                    color=colors[i])
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=11'>12</a>           )
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=12'>13</a>     pos = pos+6
#      <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X63sdW50aXRsZWQ%3D?line=14'>15</a> #plt.xticks(tick_pos, [1,2,3,4,5,6,7], rotation=0)
#
# IndexError: list index out of range

# %%
stats = []
for s in steps:
    for i in range(7):
        stats.append(cbook.boxplot_stats(scores[i][0:s], whis = whis)[0])

# %%
pos = np.arange(0, n_dists)
box_pos = len(steps)*pos + 1
box_pos += range(len(box_pos))

# Position for the x-axis tick labels (in the middle of each districts group of boxes)
tick_pos = box_pos + (len(steps)+1)/2 - 1

# %%
fig, ax = plt.subplots(figsize=(12,6))
# Looping over each subset of data (e.g, 100 trials, 1000 trials, etc.)
for i,s in enumerate(steps):
    data = stats[0+7*i:7+7*i]
    # Create the boxplots
    ax.bxp(data, positions = box_pos+i, 
           widths=0.5,
           boxprops = dict(color=colors[i]),
           flierprops = flierprops,
           medianprops = dict(linestyle='-',
                   color=colors[i])
          )
    pos = pos+6

plt.xticks(tick_pos, [1,2,3,4,5,6,7], rotation=0)
plt.ylabel('Areal Unit Segregation')
plt.text(19.5,-25,'District Index')
plt.legend(handles=[patch_1, patch_2, patch_3, patch_4, patch_5], loc='upper left')
#plt.savefig('convergence_bars')
plt.show()

# %%
df = pd.read_csv("/Users/rebeccawagner/Documents/GitHub/GerryGainMCMC/Output/Chain_02.23/scores/RunOne_segregation_1_2023-03-01-15-00-35-598748",names=[1,2,3,4,5,6,7])

# %%
df
# Out:
#               1         2         3          4         5          6          7
# 1     -0.449858 -7.150571 -3.792898 -10.025746  0.198728 -14.170530  18.428387
# 2     18.550356 -7.150571 -3.792898 -10.025746  0.198728 -14.170530  -0.531932
# 3     18.550356 -4.876559 -6.062259 -10.025746  0.198728 -14.170530  -0.531932
# 4     18.550356 -8.571489 -2.364924 -10.025746  0.198728 -14.170530  -0.531932
# 5     18.550356 -3.834800 -7.112741 -10.025746  0.198728 -14.170530  -0.531932
# ...         ...       ...       ...        ...       ...        ...        ...
# 1996 -10.056210 -3.255453 -0.101628  -2.286646  1.313939  -2.015381  -0.450059
# 1997 -10.056210  4.901154 -0.101628  -2.286646 -6.913124  -2.015381  -0.450059
# 1998 -10.056210  4.901154  0.482971  -2.861860 -6.913124  -2.015381  -0.450059
# 1999 -10.056210  4.901154  0.482971  -3.066576 -6.716270  -2.015381  -0.450059
# 2000 -10.056210  4.901154 -3.229430   0.643531 -6.716270  -2.015381  -0.450059
#
# [2000 rows x 7 columns]

# %%
df.transpose(copy=True)
# Out:
#         1          2          3          4          5          6     \
# 1  -0.449858  18.550356  18.550356  18.550356  18.550356  18.550356
# 2  -7.150571  -7.150571  -4.876559  -8.571489  -3.834800  -7.021390
# 3  -3.792898  -3.792898  -6.062259  -2.364924  -7.112741  -3.919550
# 4 -10.025746 -10.025746 -10.025746 -10.025746 -10.025746 -10.025746
# 5   0.198728   0.198728   0.198728   0.198728   0.198728   0.198728
# 6 -14.170530 -14.170530 -14.170530 -14.170530 -14.170530 -14.170530
# 7  18.428387  -0.531932  -0.531932  -0.531932  -0.531932  -0.531932
#
#         7          8          9          10    ...       1991       1992  \
# 1   0.358454   3.070203   3.070203   3.070203  ... -10.056210 -10.056210
# 2  -7.021390  -7.021390  -7.021390  -8.584359  ...  -1.342202  -1.564171
# 3  -3.919550  -3.919550  -3.919550  -2.374068  ...  -0.098020  -0.098020
# 4 -10.025746 -10.025746   1.028736   1.028736  ...  -2.622128  -2.398614
# 5   0.198728   0.198728 -10.830530 -10.830530  ...  -0.239198  -0.239198
# 6   4.315877   1.627208   1.627208   1.627208  ...  -2.015381  -2.015381
# 7  -0.531932  -0.531932  -0.531932  -0.531932  ...  -0.450059  -0.450059
#
#         1993       1994       1995       1996       1997       1998  \
# 1 -10.056210 -10.056210 -10.056210 -10.056210 -10.056210 -10.056210
# 2  -1.678079  -3.255453  -3.255453  -3.255453   4.901154   4.901154
# 3  -0.098020  -0.098020  -3.003725  -0.101628  -0.101628   0.482971
# 4  -2.289920  -2.289920   0.610755  -2.286646  -2.286646  -2.861860
# 5  -0.239198   1.313939   1.313939   1.313939  -6.913124  -6.913124
# 6  -2.015381  -2.015381  -2.015381  -2.015381  -2.015381  -2.015381
# 7  -0.450059  -0.450059  -0.450059  -0.450059  -0.450059  -0.450059
#
#         1999       2000
# 1 -10.056210 -10.056210
# 2   4.901154   4.901154
# 3   0.482971  -3.229430
# 4  -3.066576   0.643531
# 5  -6.716270  -6.716270
# 6  -2.015381  -2.015381
# 7  -0.450059  -0.450059
#
# [7 rows x 2000 columns]

# %%
df
# Out:
#               1         2         3          4         5          6          7
# 1     -0.449858 -7.150571 -3.792898 -10.025746  0.198728 -14.170530  18.428387
# 2     18.550356 -7.150571 -3.792898 -10.025746  0.198728 -14.170530  -0.531932
# 3     18.550356 -4.876559 -6.062259 -10.025746  0.198728 -14.170530  -0.531932
# 4     18.550356 -8.571489 -2.364924 -10.025746  0.198728 -14.170530  -0.531932
# 5     18.550356 -3.834800 -7.112741 -10.025746  0.198728 -14.170530  -0.531932
# ...         ...       ...       ...        ...       ...        ...        ...
# 1996 -10.056210 -3.255453 -0.101628  -2.286646  1.313939  -2.015381  -0.450059
# 1997 -10.056210  4.901154 -0.101628  -2.286646 -6.913124  -2.015381  -0.450059
# 1998 -10.056210  4.901154  0.482971  -2.861860 -6.913124  -2.015381  -0.450059
# 1999 -10.056210  4.901154  0.482971  -3.066576 -6.716270  -2.015381  -0.450059
# 2000 -10.056210  4.901154 -3.229430   0.643531 -6.716270  -2.015381  -0.450059
#
# [2000 rows x 7 columns]

# %%
df = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)

# %%
df
# Out:
#         1          2          3          4          5          6     \
# 1 -14.170530 -14.170530 -14.170530 -14.170530 -14.170530 -14.170530
# 2 -10.025746 -10.025746 -10.025746 -10.025746 -10.025746 -10.025746
# 3  -7.150571  -7.150571  -6.062259  -8.571489  -7.112741  -7.021390
# 4  -3.792898  -3.792898  -4.876559  -2.364924  -3.834800  -3.919550
# 5  -0.449858  -0.531932  -0.531932  -0.531932  -0.531932  -0.531932
# 6   0.198728   0.198728   0.198728   0.198728   0.198728   0.198728
# 7  18.428387  18.550356  18.550356  18.550356  18.550356  18.550356
#
#         7          8          9          10    ...       1991       1992  \
# 1 -10.025746 -10.025746 -10.830530 -10.830530  ... -10.056210 -10.056210
# 2  -7.021390  -7.021390  -7.021390  -8.584359  ...  -2.622128  -2.398614
# 3  -3.919550  -3.919550  -3.919550  -2.374068  ...  -2.015381  -2.015381
# 4  -0.531932  -0.531932  -0.531932  -0.531932  ...  -1.342202  -1.564171
# 5   0.198728   0.198728   1.028736   1.028736  ...  -0.450059  -0.450059
# 6   0.358454   1.627208   1.627208   1.627208  ...  -0.239198  -0.239198
# 7   4.315877   3.070203   3.070203   3.070203  ...  -0.098020  -0.098020
#
#         1993       1994       1995       1996       1997       1998  \
# 1 -10.056210 -10.056210 -10.056210 -10.056210 -10.056210 -10.056210
# 2  -2.289920  -3.255453  -3.255453  -3.255453  -6.913124  -6.913124
# 3  -2.015381  -2.289920  -3.003725  -2.286646  -2.286646  -2.861860
# 4  -1.678079  -2.015381  -2.015381  -2.015381  -2.015381  -2.015381
# 5  -0.450059  -0.450059  -0.450059  -0.450059  -0.450059  -0.450059
# 6  -0.239198  -0.098020   0.610755  -0.101628  -0.101628   0.482971
# 7  -0.098020   1.313939   1.313939   1.313939   4.901154   4.901154
#
#         1999       2000
# 1 -10.056210 -10.056210
# 2  -6.716270  -6.716270
# 3  -3.066576  -3.229430
# 4  -2.015381  -2.015381
# 5  -0.450059  -0.450059
# 6   0.482971   0.643531
# 7   4.901154   4.901154
#
# [7 rows x 2000 columns]

# %%
data_list = [df.iloc[i] for i in range(7)]

# %%
plt.boxplot([data_list[i] for i in range(7)])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16f22cfa0>,
#   <matplotlib.lines.Line2D at 0x16f22d240>,
#   <matplotlib.lines.Line2D at 0x16f22e200>,
#   <matplotlib.lines.Line2D at 0x16f22e4a0>,
#   <matplotlib.lines.Line2D at 0x16f22f460>,
#   <matplotlib.lines.Line2D at 0x16f22f700>,
#   <matplotlib.lines.Line2D at 0x16f260700>,
#   <matplotlib.lines.Line2D at 0x16f2609a0>,
#   <matplotlib.lines.Line2D at 0x16f197430>,
#   <matplotlib.lines.Line2D at 0x16f1979a0>,
#   <matplotlib.lines.Line2D at 0x16f2622f0>,
#   <matplotlib.lines.Line2D at 0x16f262590>,
#   <matplotlib.lines.Line2D at 0x16f263550>,
#   <matplotlib.lines.Line2D at 0x16f2637f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x16f22d4e0>,
#   <matplotlib.lines.Line2D at 0x16f22d780>,
#   <matplotlib.lines.Line2D at 0x16f22e740>,
#   <matplotlib.lines.Line2D at 0x16f22e9e0>,
#   <matplotlib.lines.Line2D at 0x16f22f9a0>,
#   <matplotlib.lines.Line2D at 0x16f22fc40>,
#   <matplotlib.lines.Line2D at 0x16f260c40>,
#   <matplotlib.lines.Line2D at 0x16f260ee0>,
#   <matplotlib.lines.Line2D at 0x16f261660>,
#   <matplotlib.lines.Line2D at 0x16f261870>,
#   <matplotlib.lines.Line2D at 0x16f262830>,
#   <matplotlib.lines.Line2D at 0x16f262ad0>,
#   <matplotlib.lines.Line2D at 0x16f263a90>,
#   <matplotlib.lines.Line2D at 0x16f263d30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16f22cc40>,
#   <matplotlib.lines.Line2D at 0x16f22df60>,
#   <matplotlib.lines.Line2D at 0x16f22f1c0>,
#   <matplotlib.lines.Line2D at 0x16f260460>,
#   <matplotlib.lines.Line2D at 0x16f2616c0>,
#   <matplotlib.lines.Line2D at 0x16f262050>,
#   <matplotlib.lines.Line2D at 0x16f2632b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16f22da20>,
#   <matplotlib.lines.Line2D at 0x16f22ec80>,
#   <matplotlib.lines.Line2D at 0x16f22fee0>,
#   <matplotlib.lines.Line2D at 0x16f261180>,
#   <matplotlib.lines.Line2D at 0x16f261b10>,
#   <matplotlib.lines.Line2D at 0x16f262d70>,
#   <matplotlib.lines.Line2D at 0x16f263fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16f22dcc0>,
#   <matplotlib.lines.Line2D at 0x16f22ef20>,
#   <matplotlib.lines.Line2D at 0x16f2601c0>,
#   <matplotlib.lines.Line2D at 0x16f261420>,
#   <matplotlib.lines.Line2D at 0x16f261db0>,
#   <matplotlib.lines.Line2D at 0x16f263010>,
#   <matplotlib.lines.Line2D at 0x16f2802b0>],
#  'means': []}
